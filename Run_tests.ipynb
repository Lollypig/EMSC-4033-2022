# %%
from assets import functions_map

# %%
! pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.7, pytest-7.1.2, pluggy-1.0.0
# rootdir: /home/jupyter-u6966168/EMSC-4033-project/Jupyter Notebook(s) (& Code)
# plugins: anyio-3.5.0
# collected 5 items
#
# tests/test_functions_map.py .....                                        [100%]
#
# ============================== 5 passed in 20.49s ==============================
